# %%
import pandas as pd
import numpy as np
from scipy import stats

# %%
df = pd.read_csv('Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
group_data = df.groupby('Species')

# %%
summary = group_data.agg({'SepalLengthCm' : ['mean','median','min','max','std'],
                         'SepalWidthCm' : ['mean','median','min','max','std'],
                         'PetalLengthCm' : ['mean','median','min','max','std'],
                         'PetalWidthCm' : ['mean','median','min','max','std']})
summary
# Out:
#                 SepalLengthCm                            SepalWidthCm         \
#                          mean median  min  max       std         mean median
# Species
# Iris-setosa             5.006    5.0  4.3  5.8  0.352490        3.418    3.4
# Iris-versicolor         5.936    5.9  4.9  7.0  0.516171        2.770    2.8
# Iris-virginica          6.588    6.5  4.9  7.9  0.635880        2.974    3.0
#
#                                     PetalLengthCm                             \
#                  min  max       std          mean median  min  max       std
# Species
# Iris-setosa      2.3  4.4  0.381024         1.464   1.50  1.0  1.9  0.173511
# Iris-versicolor  2.0  3.4  0.313798         4.260   4.35  3.0  5.1  0.469911
# Iris-virginica   2.2  3.8  0.322497         5.552   5.55  4.5  6.9  0.551895
#
#                 PetalWidthCm
#                         mean median  min  max       std
# Species
# Iris-setosa            0.244    0.2  0.1  0.6  0.107210
# ...

# %%
per = group_data.agg({ 'PetalLengthCm' : [('25%', lambda x : x.quantile(0.25)),('50%', lambda x : x.quantile(0.5)), ('75%', lambda x : x.quantile(0.75))],
                      'PetalWidthCm' : [('25%', lambda x : x.quantile(0.25)),('50%', lambda x : x.quantile(0.5)), ('75%', lambda x : x.quantile(0.75))],
                      'SepalLengthCm' : [('25%', lambda x : x.quantile(0.25)),('50%', lambda x : x.quantile(0.5)), ('75%', lambda x : x.quantile(0.75))], 
                      'SepalWidthCm' : [('25%', lambda x : x.quantile(0.25)),('50%', lambda x : x.quantile(0.5)), ('75%', lambda x : x.quantile(0.75))]
                     })
per
# Out:
#                 PetalLengthCm              PetalWidthCm            \
#                           25%   50%    75%          25%  50%  75%
# Species
# Iris-setosa               1.4  1.50  1.575          0.2  0.2  0.3
# Iris-versicolor           4.0  4.35  4.600          1.2  1.3  1.5
# Iris-virginica            5.1  5.55  5.875          1.8  2.0  2.3
#
#                 SepalLengthCm           SepalWidthCm
#                           25%  50%  75%          25%  50%    75%
# Species
# Iris-setosa             4.800  5.0  5.2        3.125  3.4  3.675
# Iris-versicolor         5.600  5.9  6.3        2.525  2.8  3.000
# Iris-virginica          6.225  6.5  6.9        2.800  3.0  3.175
